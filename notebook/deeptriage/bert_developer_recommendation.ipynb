# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from tqdm import tqdm

from transformers import RobertaModel, RobertaTokenizer

# %%
def load_dataframe(path: str) -> pd.DataFrame:
    return pd.read_csv(path)

# %%
def clean_data(df):
    df['text'] = df['text'].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')
    df["text"] = df['text'].str.replace(" +", " ", regex=True)

    return df
    
def prepare_dataframe(df: pd.DataFrame, minimum_contribution = 300) -> pd.DataFrame:
    developers = df["owner"].value_counts()
    # filtered_developers = developers.index[developers >= minimum_contribution]
    # df = df[df["owner"].isin(filtered_developers)]

    df["text"] = df.apply(lambda x: str(x["issue_title"]) + "\n" + str(x["description"]), axis=1)
    df["owner_id"] = pd.factorize(df["owner"])[0]

    min_length = 15
    df = df[df["text"].str.len().gt(min_length)]

    return df

# %%
data_path = "/home/mdafifal.mamun/notebooks/triagerX/notebook/data/deeptriage/classifier_data_20.csv"

df = load_dataframe(data_path)
df = prepare_dataframe(df)
df = clean_data(df)

# %%
print(df.iloc[2220]["text"])
# Out:
# possible data race in disk_cache::BackendImpl
# most likely r107425http://build.chromium.org/p/chromium.memory.fyi/builders/Chromium%20Mac%20%28tsan%29/builds/9708/steps/memory%20test%3A%20net/logs/stdio-----------------------------------------------------Suppressions used: count name 2 dyld tries to unlock an invalid mutex when adding/removing image.-----------------------------------------------------14:52:15 tsan_analyze.py [ERROR] FAIL! Found 3 report(s)14:52:15 tsan_analyze.py [ERROR] INFO: T0 is program's main threadINFO: T56 has been created by T0 at this point: {{{ #0 0x74829B4: _sysenter_trap /usr/lib/libSystem.B.dylib #1 0x74B2ED9: __bsdthread_create /usr/lib/libSystem.B.dylib #2 0x74B2DD2: pthread_create /usr/lib/libSystem.B.dylib #3 0x5C20D24: pthread_create /private/tmp/valgrind.fMHcKq/lib/valgrind/vgpreload_tsan-x86-darwin.so #4 0x7FD151: base::::CreateThread src/xcodebuild/Release/net_unittests #5 0x7FD04B: base::PlatformThread::Create src/xcodebuild/Release/net_unittests #6 0x7FDA7F: base::Thread::StartWithOptions src/xcodebuild/Release/net_unittests #7 0x227B7D: DiskCacheTestWithCache::InitDiskCache src/xcodebuild/Release/net_unittests #8 0x2275C5: DiskCacheTestWithCache::InitCache src/xcodebuild/Release/net_unittests #9 0x1FE56D: DiskCacheBackendTest::BackendTrimInvalidEntry2 src/xcodebuild/Release/net_unittests #10 0x84096D: testing::internal::HandleSehExceptionsInMethodIfSupported src/xcodebuild/Release/net_unittests}}}WARNING: Possible data race during write of size 4 at 0xB756008: {{{ T56 (CacheThread) (L{}): #0 0x5F9E58: disk_cache::BackendImpl::DecreaseNumEntries src/xcodebuild/Release/net_unittests #1 0x602A08: disk_cache::BackendImpl::DestroyInvalidEntry src/xcodebuild/Release/net_unittests #2 0x5F8463: disk_cache::BackendImpl::MatchEntry src/xcodebuild/Release/net_unittests #3 0x5F9D6B: disk_cache::BackendImpl::InternalDoomEntry src/xcodebuild/Release/net_unittests #4 0x602BE3: disk_cache::BackendImpl::GetEnumeratedEntry src/xcodebuild/Release/net_unittests #5 0x6185C8: disk_cache::Eviction::EvictEntry src/xcodebuild/Release/net_unittests #6 0x616409: disk_cache::Eviction::TrimCache src/xcodebuild/Release/net_unittests #7 0x61B4E4: base::internal::Invoker2::DoInvoke src/xcodebuild/Release/net_unittests #8 0x59D036: base::Callback::Run src/xcodebuild/Release/net_unittests #9 0x7C5F2B: MessageLoop::RunTask src/xcodebuild/Release/net_unittests Concurrent read(s) happened at (OR AFTER) these points: T0 (L{}): #0 0x601D72: disk_cache::BackendImpl::GetEntryCount src/xcodebuild/Release/net_unittests #1 0x1FECB8: DiskCacheBackendTest::BackendTrimInvalidEntry2 src/xcodebuild/Release/net_unittests #2 0x84096D: testing::internal::HandleSehExceptionsInMethodIfSupported src/xcodebuild/Release/net_unittests Location 0xB756008 is 8 bytes inside a block starting at 0xB756000 of size 262512 allocated by T56 from heap: #0 0x5C24B86: mmap /private/tmp/valgrind.fMHcKq/lib/valgrind/vgpreload_tsan-x86-darwin.so #1 0x620664: disk_cache::MappedFile::Init src/xcodebuild/Release/net_unittests #2 0x5F53D1: disk_cache::BackendImpl::InitBackingStore src/xcodebuild/Release/net_unittests #3 0x5F4F5E: disk_cache::BackendImpl::SyncInit src/xcodebuild/Release/net_unittests #4 0x61CE23: disk_cache::BackendIO::ExecuteBackendOperation src/xcodebuild/Release/net_unittests #5 0x61E8FC: base::internal::Invoker1::DoInvoke src/xcodebuild/Release/net_unittests #6 0x59D036: base::Callback::Run src/xcodebuild/Release/net_unittests #7 0x7C5F2B: MessageLoop::RunTask src/xcodebuild/Release/net_unittests Race verifier data: 0x5F9E58,0x601D72}}}Suppression (error hash=#78D9540F8E940095#): For more info on using suppressions see http://dev.chromium.org/developers/how-tos/using-valgrind/threadsanitizer#TOC-Suppressing-data-races{ <Put your suppression name here> ThreadSanitizer:Race fun:disk_cache::BackendImpl::DecreaseNumEntries fun:disk_cache::BackendImpl::DestroyInvalidEntry fun:disk_cache::BackendImpl::MatchEntry fun:disk_cache::BackendImpl::InternalDoomEntry fun:disk_cache::BackendImpl::GetEnu ...

# %%
print(len(df))
# Out:
# 109979

# %%
len(df["owner"].value_counts())
# Out:
# 1032

# %%
# df["owner"].value_counts().plot(kind="pie")

# %%
df
# Out:
#                         owner  \
# 0           amit@chromium.org
# 1            jon@chromium.org
# 2       pfeldman@chromium.org
# 3            jon@chromium.org
# 4       pkasting@chromium.org
# ...                       ...
# 109974    navabi@chromium.org
# 109975    bulach@chromium.org
# 109976  pfeldman@chromium.org
# 109977    ernstm@chromium.org
# 109978   apavlov@chromium.org
#
#                                               issue_title  \
# 0       Scrolling with some scroll mice (touchpad, etc...
# 1       Proxy causes some or all network requests to fail
# 2       Web inspector button "dock to main window" doe...
# 3        Habari admin interface is not rendered correctly
# 4           Maximize on second larger monitor not working
# ...                                                   ...
# 109974           Launch clank_qa recipes to the waterfall
# 109975                 data race in ThreadWatcherListTest
# 109976   window.console object should not be configurable
# 109977         Windows GPU bots failing on multiple tests
# 109978  CSS auto-complete suggestion list is incomplet...
#
#                                               description  \
# 0       Product Version      : <see about:version>URLs...
# 1       Product Version      : 0.2.149.27 (1583)URLs (...
# 2       Product Version      : chrome beta 1URLs (if a...
# 3       Product Version      : 0.2.149.27 (1583)URLs (...
# 4       Product Version      : 0.2.149.27URLs (if appl...
# ...                                                   ...
# 109974                                We had git trouble
# 109975  r255322 is culprithttp://build.chromium.org/p/...
# 109976  Recently sites have begun replacing window.con...
# 109977  All Windows GPU bots are failing a variety of ...
# 109978  UserAgent: Mozilla/5.0 (X11; Linux x86_64) App...
#
#                                                      text  owner_id
# 0       Scrolling with some scroll mice (touchpad, etc...         0
# 1       Proxy causes some or all network requests to f...         1
# 2       Web inspector button "dock to main window" doe...         2
# 3       Habari admin interface is not rendered correct...         1
# 4       Maximize on second larger monitor not working\...         3
# ...                                                   ...       ...
# 109974  Launch clank_qa recipes to the waterfall\nWe h...       828
# 109975  data race in ThreadWatcherListTest\nr255322 is...       556
# 109976  window.console object should not be configurab...         2
# 109977  Windows GPU bots failing on multiple tests\nAl...       588
# 109978  CSS auto-complete suggestion list is incomplet...       135
#
# [109979 rows x 5 columns]

# %%
X = df[["issue_title", "description"]]
y = df[["owner"]]

# %%
X.head()
# Out:
#                                          issue_title  \
# 0  Scrolling with some scroll mice (touchpad, etc...
# 1  Proxy causes some or all network requests to fail
# 2  Web inspector button "dock to main window" doe...
# 3   Habari admin interface is not rendered correctly
# 4      Maximize on second larger monitor not working
#
#                                          description
# 0  Product Version      : <see about:version>URLs...
# 1  Product Version      : 0.2.149.27 (1583)URLs (...
# 2  Product Version      : chrome beta 1URLs (if a...
# 3  Product Version      : 0.2.149.27 (1583)URLs (...
# 4  Product Version      : 0.2.149.27URLs (if appl...

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(112)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, stratify=y, random_state=42)

# %%
y_test["owner"].value_counts()
# Out:
# owner
# estade@chromium.org        412
# sky@chromium.org           312
# pfeldman@chromium.org      238
# ananta@chromium.org        235
# davidjames@chromium.org    228
#                           ...
# peconn@chromium.org          7
# dmazzoni...@gmail.com        7
# sunandt@chromium.org         7
# kenobi@chromium.org          7
# drinkcat@chromium.org        7
# Name: count, Length: 1032, dtype: int64

# %%
df_val["owner"].value_counts()
# Out:
# owner
# estade@chromium.org         115
# sky@chromium.org             98
# pfeldman@chromium.org        77
# ananta@chromium.org          73
# tha...@chromium.org          70
#                            ...
# aval...@chromium.org          1
# dmu...@chromium.org           1
# johnjbarton@chromium.org      1
# jvoung@chromium.org           1
# yuzo@chromium.org             1
# Name: count, Length: 1008, dtype: int64

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, df, model_name):
        self.tokenizer = RobertaTokenizer.from_pretrained(model_name)
        self.labels = [label for label in df['owner_id']]
        self.texts = [self.tokenizer(text,
                               padding='max_length', max_length = 512, truncation=True,
                                return_tensors="pt") for text in df['text']]

    def classes(self):
        return self.labels

    def __len__(self):
        return len(self.labels)

    def get_batch_labels(self, idx):
        # Fetch a batch of labels
        return np.array(self.labels[idx])

    def get_batch_texts(self, idx):
        # Fetch a batch of inputs
        return self.texts[idx]

    def __getitem__(self, idx):

        batch_texts = self.get_batch_texts(idx)
        batch_y = self.get_batch_labels(idx)

        return batch_texts, batch_y

# %%
class LBTLikeClassifier(nn.Module):
    def __init__(self, model_name: str, output_size, num_filters=256, bert_layers=4, embed_size=768, dropout = 0.1) -> None:
        super().__init__()
        self.base_model = RobertaModel.from_pretrained(model_name, output_hidden_states=True)
        filter_sizes = [3, 4, 5, 6]
        self.num_filters = num_filters
        self.bert_layers = bert_layers
        self.convs1 = nn.ModuleList([nn.Conv2d(self.bert_layers, num_filters, (K, embed_size)) for K in filter_sizes])
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(len(filter_sizes)*num_filters + embed_size, output_size)
        self.relu = nn.ReLU()

    def forward(self, input_ids, attention_mask):
        x = self.base_model(input_ids, attention_mask = attention_mask)
        hidden_states = x["hidden_states"][-self.bert_layers:]
        pooler_output = x["pooler_output"]
        x = torch.stack(hidden_states, dim=1)
        x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1]
        x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]
        x = torch.cat(x, 1)
        x = torch.cat([pooler_output, x], 1)
        x = self.dropout(x)
        logit = self.fc1(x)

        return self.relu(x)

# %%
class Classifier(nn.Module):
    def __init__(self, model_name: str, output_size, embed_size=768, dropout = 0.1) -> None:
        super().__init__()
        self.base_model = RobertaModel.from_pretrained(model_name, output_hidden_states=True)
        filter_sizes = [3, 4, 5, 6]
        num_filters = 256
        self.convs1 = nn.ModuleList([nn.Conv2d(4, num_filters, (K, embed_size)) for K in filter_sizes])
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(len(filter_sizes)*num_filters, output_size)
        self.relu = nn.ReLU()

    def forward(self, input_ids, attention_mask):
        x = self.base_model(input_ids, attention_mask = attention_mask)[2][-4:]
        x = torch.stack(x, dim=1)
        x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1] 
        x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]  
        x = torch.cat(x, 1)
        x = self.dropout(x)
        logit = self.fc1(x)  

        return self.relu(logit)

# %%
def train(model, train_data, val_data, learning_rate, epochs):
    model_name = "roberta-base"
    train, val = Dataset(train_data, model_name), Dataset(val_data, model_name)

    train_dataloader = torch.utils.data.DataLoader(train, batch_size=5, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(val, batch_size=5)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=learning_rate)

    if use_cuda:

            model = model.cuda()
            criterion = criterion.cuda()

    for epoch_num in range(epochs):

            total_acc_train = 0
            total_loss_train = 0

            for train_input, train_label in tqdm(train_dataloader):
                # print(train_label)

                train_label = train_label.to(device)
                mask = train_input['attention_mask'].to(device)
                input_id = train_input['input_ids'].squeeze(1).to(device)

                output = model(input_id, mask)

                # print(output, train_label)
                # print(output.shape, train_label.shape)

                batch_loss = criterion(output, train_label.view(-1))
                total_loss_train += batch_loss.item()

                acc = (output.argmax(dim=1) == train_label).sum().item()
                total_acc_train += acc

                model.zero_grad()
                batch_loss.backward()
                optimizer.step()

            total_acc_val = 0
            total_loss_val = 0

            with torch.no_grad():

                for val_input, val_label in val_dataloader:

                    val_label = val_label.to(device)
                    mask = val_input['attention_mask'].to(device)
                    input_id = val_input['input_ids'].squeeze(1).to(device)

                    output = model(input_id, mask)

                    batch_loss = criterion(output, val_label.long())
                    total_loss_val += batch_loss.item()

                    acc = (output.argmax(dim=1) == val_label).sum().item()
                    total_acc_val += acc

            print(
                f'Epochs: {epoch_num + 1} | Train Loss: {total_loss_train / len(train_data): .3f} \
                | Train Accuracy: {total_acc_train / len(train_data): .3f} \
                | Val Loss: {total_loss_val / len(val_data): .3f} \
                | Val Accuracy: {total_acc_val / len(val_data): .3f}')

EPOCHS = 40
num_classes = len(df["owner"].unique())
model = Classifier("roberta-base", num_classes)
LR = 1e-6

train(model, df_train, df_val, LR, EPOCHS)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   3%|████                                                                                                                                            | 492/17597 [01:32<53:24,  5.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 76
#      73 model = Classifier("roberta-base", num_classes)
#      74 LR = 1e-6
# ---> 76 train(model, df_train, df_val, LR, EPOCHS)
#
# Cell In[17], line 27, in train(model, train_data, val_data, learning_rate, epochs)
#      22 total_loss_train = 0
#      24 for train_input, train_label in tqdm(train_dataloader):
#      25     # print(train_label)
# ---> 27     train_label = train_label.to(device)
#      28     mask = train_input['attention_mask'].to(device)
#      29     input_id = train_input['input_ids'].squeeze(1).to(device)
#
# KeyboardInterrupt:
