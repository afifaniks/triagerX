# %% [markdown]
# <a href="https://colab.research.google.com/github/afifaniks/triagerX/blob/main/notebook/Fine_Tune_Llama_2_with_LoRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Oct 16 14:56:56 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100 80G...  On   | 00000000:17:00.0 Off |                    0 |
# | N/A   31C    P0    51W / 300W |      0MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 torch scipy pandas matplotlib
# Out:
# Requirement already satisfied: accelerate==0.21.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: peft==0.4.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: bitsandbytes==0.40.2 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (0.40.2)
# Requirement already satisfied: transformers==4.31.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (4.31.0)
# Requirement already satisfied: trl==0.4.7 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (0.4.7)
# Requirement already satisfied: torch in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: scipy in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (1.11.2)
# Requirement already satisfied: pandas in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: matplotlib in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from accelerate==0.21.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from accelerate==0.21.0) (23.1)
# Requirement already satisfied: psutil in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from accelerate==0.21.0) (5.9.0)
# Requirement already satisfied: pyyaml in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from accelerate==0.21.0) (6.0.1)
# Requirement already satisfied: safetensors in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from peft==0.4.0) (0.3.3)
# Requirement already satisfied: filelock in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers==4.31.0) (3.12.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers==4.31.0) (0.17.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers==4.31.0) (2023.8.8)
# Requirement already satisfied: requests in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers==4.31.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers==4.31.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers==4.31.0) (4.66.1)
# Requirement already satisfied: datasets in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from trl==0.4.7) (2.14.5)
# Requirement already satisfied: typing-extensions in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (68.0.0)
# Requirement already satisfied: wheel in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: cmake in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: fsspec in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (2023.6.0)
# Requirement already satisfied: six>=1.5 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from datasets->trl==0.4.7) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from datasets->trl==0.4.7) (0.3.7)
# Requirement already satisfied: xxhash in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from datasets->trl==0.4.7) (3.3.0)
# Requirement already satisfied: multiprocess in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from datasets->trl==0.4.7) (0.70.15)
# Requirement already satisfied: aiohttp in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from datasets->trl==0.4.7) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers==4.31.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers==4.31.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers==4.31.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers==4.31.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.4.7) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.4.7) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.4.7) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.4.7) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.4.7) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.4.7) (1.3.1)

# %%
import os
import re
import torch
from datasets import load_dataset
import pandas as pd
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
    StoppingCriteria, 
    StoppingCriteriaList
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %% [markdown]
# ## Data Exploration

# %%
data_path = "data/openj9/openj9_issues.csv"
df = pd.read_csv(data_path)
df = df.drop("Unnamed: 0", axis=1)

df.head()
# Out:
#    issue_number                                          issue_url  \
# 0            10   https://github.com/eclipse-openj9/openj9/pull/10
# 1            15   https://github.com/eclipse-openj9/openj9/pull/15
# 2            17   https://github.com/eclipse-openj9/openj9/pull/17
# 3            22   https://github.com/eclipse-openj9/openj9/pull/22
# 4            24  https://github.com/eclipse-openj9/openj9/issue...
#
#                                          issue_title  \
# 0     Update README.md with proper AdoptOpenJDK link
# 1             Refactor and clean up CodeCacheManager
# 2    WIP Add support for function pointers in Panama
# 3                       fix illegal-access behaviour
# 4  Enable a travis.ci-based PR build for linux x8...
#
#                                           issue_body issue_state      creator  \
# 0  Also remove the the coming soon reference, sin...      closed     pshipton
# 1  - Change invocation parameters of superclass c...      closed     lmaisons
# 2  When invoking a native function (with Panama) ...      closed       tajila
# 3  fix illegal-access behaviour\r\n\r\nThis is th...      closed       tajila
# 4  Build a basic PR build based off the linux_x86...      closed  DanHeidinga
#
#                                             comments      assignees
# 0                                                NaN  charliegracie
# 1  <comment><user>lmaisons</user><body>This has a...        0xdaryl
# 2  <comment><user>tajila</user><body>Thanks for t...    DanHeidinga
# 3  <comment><user>DanHeidinga</user><body>@tajila...    DanHeidinga
# 4  <comment><user>mgaudet</user><body>This has be...    DanHeidinga

# %%
df[5000:5005]
# Out:
#       issue_number                                          issue_url  \
# 5000         16649  https://github.com/eclipse-openj9/openj9/issue...
# 5001         16650  https://github.com/eclipse-openj9/openj9/pull/...
# 5002         16652  https://github.com/eclipse-openj9/openj9/issue...
# 5003         16655  https://github.com/eclipse-openj9/openj9/issue...
# 5004         16656  https://github.com/eclipse-openj9/openj9/issue...
#
#                                             issue_title  \
# 5000  Scripts not permitted to use staticMethod org....
# 5001       Implement JITServer AOT cache thunk handling
# 5002                 Skynet failures on larger machines
# 5003  jdk20 OpenJDK java/lang/Class/getEnumConstants...
# 5004  jdk20 OpenjDK java/lang/Thread/jni/AttachCurre...
#
#                                              issue_body issue_state  \
# 5000  https://openj9-jenkins.osuosl.org/job/Test_ope...      closed
# 5001  These commits add J2I thunk handling to the JI...      closed
# 5002  The Skynet test fails readily (maybe 1 in 5 ru...      closed
# 5003  https://openj9-jenkins.osuosl.org/job/Test_ope...      closed
# 5004  https://openj9-jenkins.osuosl.org/job/Test_ope...      closed
#
#          creator                                           comments  \
# 5000    pshipton  <comment><user>llxia</user><body>`makeTap13Yam...
# 5001  cjjdespres  <comment><user>cjjdespres</user><body>Attn @mp...
# 5002     0xdaryl  <comment><user>0xdaryl</user><body>FYI @fengxu...
# 5003    pshipton                                                NaN
# 5004    pshipton  <comment><user>pshipton</user><body>@tajila fy...
#
#           assignees
# 5000  AdamBrousseau
# 5001         mpirvu
# 5002      LinHu2016
# 5003       pshipton
# 5004       babsingh

# %%
total_contributors = len(df["assignees"].unique())
print(f"Total contributors: {total_contributors}")
# Out:
# Total contributors: 127

# %%
minimum_contribution = 30

developers = df["assignees"].value_counts()

# %%
filtered_developers = developers.index[developers >= minimum_contribution]

# %%
filtered_df = df[df["assignees"].isin(filtered_developers)]

# %%
filtered_df["assignees"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='assignees'>

# %%
filtered_df.to_csv("data/openj9/openj9_issues_cleaned.csv")

# %% [markdown]
# ## Model Configuration

# %%
model_name = "NousResearch/Llama-2-13b-chat-hf"
data_path = "data/openj9/openj9_issues_cleaned.csv"
new_model = "llama-2-13b-openj9"

# Set QLoRA configuration
lora_r = 64 # Attention dimension/rank
lora_alpha = 16
lora_dropout = 0.05

# Set bitsandbytes configuration
use_4bit = True #For  4-bit precision base model loading
bnb_4bit_compute_dtype = "float16" # Compute dtype for 4-bit base models
bnb_4bit_quant_type = "nf4" # Quantization type (fp4 or nf4)
use_nested_quant = False # Activate nested quantization for 4-bit base models (double quantization)


# Set training params
output_dir = "./results"
num_train_epochs = 1
fp16 = False
bf16 = False
per_device_train_batch_size = 8
per_device_eval_batch_size = 8
gradient_accumulation_steps = 1
gradient_checkpointing = True
max_grad_norm = 0.3
learning_rate = 2e-4
weight_decay = 0.001
optim = "paged_adamw_32bit"
lr_scheduler_type = "cosine"
max_steps = 300
warmup_ratio = 0.03
group_by_length = True # Group sequences into batches with same length saves memory and speeds up training considerably
save_steps = 0
logging_steps = 5

# Set SFT parameters
max_seq_length = None
packing = False # Pack multiple short examples in the same input sequence to increase efficiency
device_map = {"": 0} # Load the entire model on the GPU 0

# %%
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# %% [markdown]
# ## Load Base Model

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config, # Using it for optimized model loading
    device_map=device_map
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# !pip install --no-cache-dir transformers sentencepiece
# Out:
# Requirement already satisfied: transformers in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (4.31.0)
# Requirement already satisfied: sentencepiece in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (0.1.99)
# Requirement already satisfied: filelock in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (3.12.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, use_fast=False)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix overflow issue with fp16 training

# %% [markdown]
# ## Prompt Template Generation

# %%
# formatted_text = f"<s><INST>Issue Title:\n{data['issue_title'][i]}" \
#     + f"\nIssue Description:\n{data['description'][i]}\nWho can fix this issue?\n</INST>The issue can be fixed by: {data['owner'][i]}</s>"

import xml.etree.ElementTree as ET

def parse_comments(comments: str):
    xml_like =  ET.ElementTree(ET.fromstring(comments))

def generate_prompt_with_answer(entry, i):
    # comments = entry["comments"] # TBD

    issue_title = entry["issue_title"][i]
    issue_description = entry["issue_body"][i]
    assignees = entry["assignees"][i]
    
    prompt = f"""<s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
Developer List: {", ".join(filtered_developers.values)}

Issue Title: {issue_title}

Issue Description: {issue_description}
=====
Question: Which developer from the given Developer List can fix this issue?</INST>

Answer: {assignees}</s>
"""

    return prompt

def generate_prompt_without_answer(entry):
    issue_title = entry["issue_title"]
    issue_description = entry["issue_body"]

    prompt = f"""<s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
Developer List: {", ".join(filtered_developers.values)}

Issue Title: {issue_title}

Issue Description: {issue_description}
=====
Question: Which developer from the given Developer List can fix this issue?</INST>

Answer: </s>
"""

    return prompt

# %%
print(generate_prompt_with_answer(filtered_df, 477))
# Out:
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: zLinux compilation failing
#
# Issue Description: https://ci.eclipse.org/openj9/job/Build-JDK8-linux_390-64_cmprssptrs/318/
# https://ci.eclipse.org/openj9/job/Build-JDK9-linux_390-64_cmprssptrs/257/
# https://ci.eclipse.org/openj9/job/Build-JDK10-linux_390-64_cmprssptrs/156/
# ```
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp: In static member function ‘static TR::Register* J9::Z::TreeEvaluator::VMgenCoreInstanceofEvaluator(TR::Node*, TR::CodeGenerator*, TR::LabelSymbol*, TR::LabelSymbol*, bool, bool, TR::RegisterDependencyConditions*, bool)’:
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4356:7: error: ‘RegDep’ is not a member of ‘TR::RealRegister’
# 00:40:14        TR::RealRegister::RegDep scratch1RegAssignment;
# 00:40:14        ^
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4356:32: error: expected ‘;’ before ‘scratch1RegAssignment’
# 00:40:14        TR::RealRegister::RegDep scratch1RegAssignment;
# 00:40:14                                 ^
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4364:10: error: ‘scratch1RegAssignment’ was not declared in this scope
# 00:40:14           scratch1RegAssignment = (needsHelperCall) ?  static_cast<TR::RealRegister::RegDep>(cg->getEntryPointRegister()) : TR::RealRegister::AssignAny;
# 00:40:14           ^
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4364:67: error: expected type-specifier
# 00:40:14           scratch1RegAssignment = (needsHelperCall) ?  static_cast<TR::RealRegister::RegDep>(cg->getEntryPointRegister()) : TR::RealRegister::AssignAny;
# 00:40:14                                                                    ^
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4364:67: error: expected ‘>’
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4364:67: error: expected ‘(’
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4364:67: error: ‘RegDep’ is not a member of ‘TR::RealRegister’
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4364:122: error: expected ‘)’ before ‘:’ token
# 00:40:14           scratch1RegAssignment = (needsHelperCall) ?  static_cast<TR::RealRegister::RegDep>(cg->getEntryPointRegister()) : TR::RealRegister::AssignAny;
# 00:40:14                                                                                                                           ^
# 00:40:14 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/z/codegen/J9TreeEvaluator.cpp:4374:49: error: ‘scratch1RegAssignment’ was not declared in this scope
# 00:40:14        conditions->addPostCondition(scratch1Reg, scratch1RegAssignment);
# 00:40:14                                                  ^
# 00:40:15 /home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../compiler/build/rules/gnu/common.mk:66: recipe for target '/home/jenkins/jenkins-agent/workspace/Build-JDK8-linux_390-64_cmprssptrs/build/linux-s390x-normal-server-release/vm/compiler/../objs/compiler/z/codegen/J9TreeEvaluator.o' failed
# ```
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: fjeremic</s>

# %% [markdown]
# ## Test Base Model

# %%
device = f'cuda:{torch.cuda.current_device()}' if torch.cuda.is_available() else 'cpu'
stop_list = ['\nHuman:', '\n```\n']

stop_token_ids = [tokenizer(x)['input_ids'] for x in stop_list]
stop_token_ids = [torch.LongTensor(x).to(device) for x in stop_token_ids]

class StopOnTokens(StoppingCriteria):
    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        for stop_ids in stop_token_ids:
            if torch.eq(input_ids[0][-len(stop_ids):], stop_ids).all():
                return True
        return False

stopping_criteria = StoppingCriteriaList([StopOnTokens()])

# %%
def inference(model, tokenizer, prompt, max_length=20):
  total_response_length = len(tokenizer.tokenize(prompt)) + 8 + max_length
  pipe = pipeline(task="text-generation", model=model, max_length=total_response_length, tokenizer=tokenizer, stopping_criteria=stopping_criteria)
  result = pipe(prompt)

  return result[0]["generated_text"]

# %%
print(inference(model, tokenizer, generate_prompt_without_answer(filtered_df.iloc[300])))
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Create a disableZEC12 alias for disableZHelix
#
# Issue Description: To stay consistent with all the other processor options we create a
# disableZEC12 option and mark the previous disableZHelix as deprecated.
# Unfortunately there are references on the web to the disableZHelix
# option so we cannot completely remove it at this moment.
#
# Depends on eclipse/omr#2384.
#
# Signed-off-by: Filip Jeremic <fjeremic@ca.ibm.com>
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Based on the information provided, I would suggest that Filip Jeremic (fjeremic) can fix this issue. The

# %% [markdown]
# ## Setup Training Pipeline

# %%
dataset = load_dataset("csv", data_files=data_path, split="train")
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
def format_dataset(data):
    output_texts = []
    
    for i in range(len(data["issue_number"])):
        formatted_text = generate_prompt_with_answer(data, i)
        output_texts.append(formatted_text)

    return output_texts

# %%
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)
    else:
      print(f"Using {compute_dtype}")
# Out:
# ================================================================================
# Your GPU supports bfloat16: accelerate training with bf16=True
# ================================================================================

# %%
model.config.use_cache = False
model.config.pretraining_tp = 1

peft_config = LoraConfig(
    r=lora_r,
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    bias="none",
    task_type="CAUSAL_LM",
)

training_params = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
)

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_params,
    packing=packing,
    formatting_func=format_dataset
)

trainer.train()
trainer.model.save_pretrained(new_model)
# Out:
# /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/4958 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 15:26, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.430200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.659100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.112900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.820000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.164300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.336500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.844400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.685600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.574600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.459900</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.218200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.233400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.077800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.882400</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.803000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.718200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.605300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.565100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.482800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.422500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.144300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.181100</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.990200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.881200</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.790300</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.712400</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.617400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.514200</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.445400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.404000</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>1.073000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.205100</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>1.032100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.872400</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.752200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.625300</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.618000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.499400</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.477300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.378500</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>1.101500</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.104000</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>1.055700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.869200</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.745400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.641600</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.539800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.536500</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.451800</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.391800</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>1.134800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.103100</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>1.018600</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.825200</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.752000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.661200</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.554200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.475200</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.469400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.361200</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Merge LoRA Weights with Base Model

# %%
model_name, new_model
# Out:
# ('NousResearch/Llama-2-13b-chat-hf', 'llama-2-13b-openj9')

# %%
# !pip install protobuf
# Out:
# Collecting protobuf
#   Obtaining dependency information for protobuf from https://files.pythonhosted.org/packages/c8/2c/03046cac73f46bfe98fc846ef629cf4f84c2f59258216aa2cc0d22bfca8f/protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 2.5 MB/s eta 0:00:000:00:010:00:01
# Installing collected packages: protobuf
# Successfully installed protobuf-4.24.4

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)
model = PeftModel.from_pretrained(base_model, new_model)
model = model.merge_and_unload()

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
import random


for i in range(10):
    print(f"Observation: {i + 1}")
    print("=====================================================================================")
    prompt_template = generate_prompt_without_answer(filtered_df.iloc[random.randint(0, len(filtered_df) - 1)])
    print(inference(model, tokenizer, prompt_template, 30))
    print("\n\n============================================================================================\n\n")
# Out:
# Observation: 1
# =====================================================================================
# /home/mdafifal.mamun/miniconda3/envs/triagerx/lib/python3.10/site-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Return false when invalidating IProfiler entries
#
# Issue Description: nan
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Can you provide more information about the question?
#
# Answer: No
# =====
#
# Question: Is the answer "
#
#
# ============================================================================================
#
#
# Observation: 2
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Remove 2.9 and "IBM J9" from java.fullversion system property
#
# Issue Description: Partly addresses Issue #1020, as "2.9" is removed from the
# java.fullversion system property.
#
# The change makes the internal computation of local variables
# vminfo and fullversion the same, so fullversion is removed. Note, at
# runtime the system property java.fullversion is currently prepended with
# additional build information.
#
# Fixes: #1012
#
# Signed-off-by: Peter Shipton <Peter_Shipton@ca.ibm.com>
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
#
#
# ============================================================================================
#
#
# Observation: 3
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Implement New Lock Reservation scheme on Power
#
# Issue Description: This commit is for a new lock reservation scheme that is currently only active on power.
#
# The new lock reservation scheme adds a new Learning phase before a lock is reserved. During the Learning phase a lock reservation cancellation is not required if a second thread wishes to lock an object. If the Learning phase is successful, the object can be reserved.
#
# If two threads attempt to lock the same object, then it can never be reserved again. Under the old system, lock reservation could be attempted again on the same object even after a reservation on the object was cancelled.
#
# A system to bypass the new Learning state is added via new initial lockwords. Data is collected on a per class basis to try and predict if locked objects of that class will eventually go to Flat or Reserved. Based on that data, objects might go straight to Flat or Reserved when they are locked for the first time.
#
# To activate the new lock reservation scheme use the -XX:+GlobalLockReservation command line option. Without the option, the lock reservation system used will be very similar to the original system.
#
# Minor changes to x86 codegen were made to accomadate the lockword format change required to implement the new lock reservation scheme.
#
# This also removes much of the unused PPC Monitor Snippet code.
#
# More details can be found in the documentation at:
# doc/compiler/ObjectLockword.md
#
# Implements: https://github.com/eclipse/openj9/issues/8045
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Is the answer correct?
#
# Answer: Yes
# =====
#
# Question: Is the answer correct?
#
# Answer
#
#
# ============================================================================================
#
#
# Observation: 4
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: AArch64: Set correct entry point instructions in createPrologue()
#
# Issue Description: This commit changes the code for setting the entry point instructions
# in createPrologue().
# The existing code sets the linkage info word to
# interpretedMethodEntryPoint, and the last instruction from
# loadStackParametersToLinkageRegisters() to jittedMethodEntryPoint,
# respectively, instead of expected instructions.
#
# Signed-off-by: KONNO Kazuhiro <konno@jp.ibm.com>
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Is the answer correct?
#
# Answer: Yes
# =====
#
# Question: Is the answer correct?
#
# Answer
#
#
# ============================================================================================
#
#
# Observation: 5
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: WIP: Enter VM before performing JNI critical operations
#
# Issue Description: To avoid potential race conditions between exclusive VM access and JNI
# critical, always enter the VM before performing JNI critical
# acquire/release.
#
# [ci skip]
#
# Signed-off-by: Graham Chapman <graham_chapman@ca.ibm.com>
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Can the issue be fixed by the given developer?
#
# Answer: Yes
# =====
# Question: Does the issue need
#
#
# ============================================================================================
#
#
# Observation: 6
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Correctly handle modifications to Object
#
# Issue Description: Handle or disallow load-time and HCR-time modifications to java/lang/Object.
#
# Examples:
#
# - finalize becoming non-empty
# - hard-coding of the known final methods
# - assumptions on hashCode
# - assumptions on clone
#
# Related: #4714
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Is the answer correct?
#
# Answer: Yes
# =====
#
# Question: Does the answer change if the Developer
#
#
# ============================================================================================
#
#
# Observation: 7
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Fix bytecode size tables
#
# Issue Description: Fix errors introduced in #3416
#
# [ci skip]
#
# Signed-off-by: Graham Chapman <graham_chapman@ca.ibm.com>
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Is the answer correct?
#
# Answer: Yes
# =====
#
# Question: Does the answer change the information provided in
#
#
# ============================================================================================
#
#
# Observation: 8
# =====================================================================================
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (4096). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: jdk19 Jep425Tests_testVirtualThread_0 crash vmState=0x00000000
#
# Issue Description: https://openj9-jenkins.osuosl.org/job/Test_openjdk19_j9_sanity.functional_aarch64_linux_OpenJDK19_testList_0/9
# Jep425Tests_testVirtualThread_0
#
# https://openj9-artifactory.osuosl.org/artifactory/ci-openj9/Test/Test_openjdk19_j9_sanity.functional_aarch64_linux_OpenJDK19_testList_0/9/functional_test_output.tar.gz
#
# ```
# Unhandled exception
# Type=Segmentation error vmState=0x00000000
# J9Generic_Signal_Number=00000018 Signal_Number=0000000b Error_Value=00000000 Signal_Code=00000001
# Handler1=0000FFFFB1529720 Handler2=0000FFFFB14915D0 InaccessibleAddress=FFFFFFFFFFFFFF80
# R0=0000000000000000 R1=0000FFFF89D9C590 R2=0000FFFFB16C7000 R3=FFFFFFFFFFFFFF80
# R4=0000000000180200 R5=000000000000000E R6=0000000000000000 R7=0000000084A5E518
# R8=0000FFFF90672C18 R9=0000000000000000 R10=00000000003AD2E0 R11=0000000000000A1C
# R12=00002D31C8F06DEE R13=0000000000000001 R14=0000FFFF89D99F50 R15=0000000084A5ED68
# R16=0000000000000001 R17=0000FFFFB1B2B150 R18=0000000000000008 R19=0000000000180200
# R20=00000000003AD6B0 R21=0000FFFF5962FBC2 R22=0000FFFFB16C7000 R23=0000000084A52498
# R24=0000000084A52498 R25=0000FFFFB16847B4 R26=0000000000010640 R27=0000FFFFB16CB2B8
# R28=0000FFFFB1578F20 R29=0000FFFF89D99C10 R30=0000FFFFB157A5B0 R31=0000FFFF89D99C00
# PC=0000FFFFB157A7EC SP=0000FFFF89D99C00 PSTATE=0000000060001000
# V0 00000000003ad6d8 (f: 3856088.000000, d: 1.905161e-317)
# V1 ffffffffffffffff (f: 4294967296.000000, d: -nan)
# V2 0000ffff060d4931 (f: 101534000.000000, d: 1.390650e-309)
# V3 00000000003a6390 (f: 3826576.000000, d: 1.890580e-317)
# V4 0000000000022d08 (f: 142600.000000, d: 7.045376e-319)
# V5 0000000000022d68 (f: 142696.000000, d: 7.050119e-319)
# V6 0000000000022d68 (f: 142696.000000, d: 7.050119e-319)
# V7 00000000003a6310 (f: 3826448.000000, d: 1.890517e-317)
# V8 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V9 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V10 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V11 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V12 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V13 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V14 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V15 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V16 4010040140100401 (f: 1074791424.000000, d: 4.003911e+00)
# V17 fe00fcfcfe00fcfc (f: 4261477632.000000, d: -8.888203e+298)
# V18 3fcc71c51d8e78af (f: 495876256.000000, d: 2.222220e-01)
# V19 3fc7466496cb03de (f: 2529887232.000000, d: 1.818357e-01)
# V20 c36d58c876160284 (f: 1981153920.000000, d: -6.608314e+16)
# V21 df9cad5d29c8b2bb (f: 701018816.000000, d: -3.754867e+152)
# V22 efcdab8967452301 (f: 1732584192.000000, d: -3.598696e+230)
# V23 3fc999999999999a (f: 2576980480.000000, d: 2.000000e-01)
# V24 3fd6666666666666 (f: 1717986944.000000, d: 3.500000e-01)
# V25 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V26 3fb999999999999a (f: 2576980480.000000, d: 1.000000e-01)
# V27 000000000000000a (f: 10.000000, d: 4.940656e-323)
# V28 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V29 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V30 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V31 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# Module=/home/jenkins/workspace/Test_openjdk19_j9_sanity.functional_aarch64_linux_OpenJDK19_testList_0/openjdkbinary/j2sdk-image/lib/default/libj9vm29.so
# Module_base_address=0000FFFFB14F8000
# Target=2_90_20220803_11 (Linux 5.4.0-122-generic)
# CPU=aarch64 (8 logical CPUs) (0x1effae000 RAM)
# ----------- Stack Backtrace -----------
# Unhandled exception
# Type=Segmentation error vmState=0x00000000
# J9Generic_Signal_Number=00000018 Signal_Number=0000000b Error_Value=00000000 Signal_Code=00000001
# Handler1=0000FFFFB1529720 Handler2=0000FFFFB14915D0 InaccessibleAddress=FFFFFFFFFFFFFF80
# R0=0000000000000000 R1=0000FFFF89841590 R2=0000FFFFB16C7000 R3=FFFFFFFFFFFFFF80
# R4=00000000003C0200 R5=000000000000000E R6=0000FFFF70001B48 R7=0000FFFFAC10AB40
# R8=0000000000000000 R9=0000000000000000 R10=00000000003BF930 R11=0000000000000018
# R12=000000000000001E R13=0000000000000006 R14=0000FFFF8983FFF0 R15=0000000000000018
# R16=0000000000000001 R17=0000FFFFB1C385F8 R18=0000FFFF89840520 R19=00000000003C0200
# R20=00000000003BFD00 R21=0000FFFF5962FBC2 R22=0000FFFFB16C7000 R23=0000000084A52498
# R24=0000000084A52498 R25=0000FFFFB16847B4 R26=0000000000010640 R27=0000FFFFB16CB2B8
# R28=0000FFFFB1578F20 R29=0000FFFF8983FCB0 R30=0000FFFFB157A5B0 R31=0000FFFF8983FCA0
# PC=0000FFFFB157A7EC SP=0000FFFF8983FCA0 PSTATE=0000000060001000
# V0 00000000003bfd28 (f: 3931432.000000, d: 1.942385e-317)
# V1 0000000084a864e0 (f: 2225628416.000000, d: 1.099607e-314)
# V2 8689587b072ae131 (f: 120250672.000000, d: -3.574514e-277)
# V3 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V4 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V5 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V6 3fe62e42fefa39ef (f: 4277811712.000000, d: 6.931472e-01)
# V7 8020080280200802 (f: 2149582848.000000, d: -4.458850e-308)
# V8 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V9 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V10 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V11 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V12 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V13 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V14 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V15 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V16 4010040140100401 (f: 1074791424.000000, d: 4.003911e+00)
# V17 00000000feff0000 (f: 4278124544.000000, d: 2.113674e-314)
# V18 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V19 ca62c1d6ca62c1d6 (f: 3395469824.000000, d: -2.193092e+50)
# V20 c36d58c876160284 (f: 1981153920.000000, d: -6.608314e+16)
# V21 df9cad5d29c8b2bb (f: 701018816.000000, d: -3.754867e+152)
# V22 efcdab8967452301 (f: 1732584192.000000, d: -3.598696e+230)
# V23 3fc999999999999a (f: 2576980480.000000, d: 2.000000e-01)
# V24 3fd6666666666666 (f: 1717986944.000000, d: 3.500000e-01)
# V25 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V26 3fb999999999999a (f: 2576980480.000000, d: 1.000000e-01)
# V27 000000000000000a (f: 10.000000, d: 4.940656e-323)
# V28 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V29 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V30 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# V31 0000000000000000 (f: 0.000000, d: 0.000000e+00)
# Module=/home/jenkins/workspace/Test_openjdk19_j9_sanity.functional_aarch64_linux_OpenJDK19_testList_0/openjdkbinary/j2sdk-image/lib/default/libj9vm29.so
# Module_base_address=0000FFFFB14F8000
# Target=2_90_20220803_11 (Linux 5.4.0-122-generic)
# CPU=aarch64 (8 logical CPUs) (0x1effae000 RAM)
# ----------- Stack Backtrace -----------
# bytecodeLoopCompressed+0x18cc (0x0000FFFFB157A7EC [libj9vm29.so+0x827ec])
# c_cInterpreter+0x54 (0x0000FFFFB15FD4A8 [libj9vm29.so+0x1054a8])
# ---------------------------------------
# ```
#
# @tajila fyi
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ============================================================================================
#
#
# Observation: 9
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Fix -install_name on OSX
#
# Issue Description: On OSX, <LIB_NAME_DYLIB>.dylib should match the -install_name
# <LIB_NAME_INSTALL>. Otherwise, the linker is unable to find the required
# library. Currently, LIB_NAME_DYLIB doesn't match LIB_NAME_INSTALL.
# LIB_NAME_DYLIB has major and minor build versions appended whereas
# LIB_NAME_INSTALL doesn't contain version info. UMA_LIB_NAME will contain
# LIB_NAME_INSTALL with major and minor build versions.
#
# UMA_LIB_NAME will be used to specify -install_name. With this change,
# the linker is able to find the required libraries on OSX, and OpenJ9 can
# be built successfully with the JIT disabled. Other platforms shouldn't
# be impacted since UMA_LIB_NAME is only used on OSX.
#
# [ci skip]
#
# Signed-off-by: Babneet Singh <sbabneet@ca.ibm.com>
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Is the answer correct?
#
# Answer: Yes
# =====
#
# Question: Does the answer change the information provided in
#
#
# ============================================================================================
#
#
# Observation: 10
# =====================================================================================
# <s><INST>Suggest a developer from the given developer list based on the issue title and description given below. The name of developers are separated by comma. You have to choose only one based on previous knowledge. If the question cannot be answered using the information provided answer with "I don't know".
# Developer List: DanHeidinga, mpirvu, 0xdaryl, pshipton, fjeremic, keithc-ca, knn-k, dsouzai, andrewcraik, JasonFengJ9, gacholio, dmitripivkine, babsingh, vijaysun-omr, hzongaro, ymanton, gita-omr, ChengJin01, fengxue-IS, jdmpapin, tajila, amicic, charliegracie, llxia, joransiu, a7ehuo
#
# Issue Title: Change API used for computing code cache size in low memory environments
#
# Issue Description: PR #17425 introduced a change for limiting the total size of the Code Cache to no more than 25% of available physical memory. This is done based on the output from the `computeAndCacheFreePhysicalMemory()` function. This function takes into consideration the amount of physical memory installed on the machine and the limits imposed by cgroups, but also looks at how much free physical memory is available (not used by other proceses) at the moment of the call. Thus, if there is a transient and very narrow spike of memory usage by some other process when our JVM starts, the JVM may think that it has very limitted physical memory and allocate a very small code cache repository.
# This commit changes the function used for computing physical memory to `omrsysinfo_get_addressable_physical_memory()` which looks at how much physical memory the JVM is allowed to use, rather than at how much physical memory is available.
# =====
# Question: Which developer from the given Developer List can fix this issue?</INST>
#
# Answer: </s>
#
# Answer: pshipton
# =====
# Question: Is the answer correct?
#
# Answer: Yes
# =====
#
# Question: Is the answer correct?
#
# Answer
#
#
# ============================================================================================

# %% [markdown]
# ## Test Fine-Tuned Model

# %%
# try:
#     del tokenizer
#     del model
#     del base_model
# except:
#     pass

# %%
hf_custom_model_path = f"afifaniks/{new_model}"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)

# %%
model = PeftModel.from_pretrained(model, hf_custom_model_path)
model = model.merge_and_unload()

# %%
print(inference(model, tokenizer, "Why birds don't have wheels?"))

# %%
print(inference(model, tokenizer, "Can you write some Delphi code that uses named pipes?"))

# %%
print(inference(model, tokenizer, "Which is a species of fish? Tope or Rope"))
